# %%
import tensorflow as tf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split

iris = load_iris()

# %%
# Load data into a DataFrame
df = pd.DataFrame(iris.data, columns=iris.feature_names)
# Convert datatype to float
df = df.astype(float)
# append "target" and name it "label"
df['label'] = iris.target
# Use string label instead
df['label'] = df.label.replace(dict(enumerate(iris.target_names)))

# %%
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#     label
# 0  setosa
# 1  setosa
# 2  setosa
# 3  setosa
# 4  setosa

# %% [markdown]
# # Prepare data for tensorflow and keras

# %%
# label -> one-hot encoding
label = pd.get_dummies(df['label'])
label.columns = ['label_' + str(x) for x in label.columns]
df = pd.concat([df, label], axis=1)

# drop old label
df.drop(['label'], axis=1, inplace=True)

# %%
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    label_setosa  label_versicolor  label_virginica
# 0             1                 0                0
# 1             1                 0                0
# 2             1                 0                0
# 3             1                 0                0
# 4             1                 0                0

# %%
# Creating X and y

X = df[['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)']]
# Convert DataFrame into np array
X = np.asarray(X)

y = df[['label_setosa', 'label_versicolor', 'label_virginica']]
# Convert DataFrame into np array
y = np.asarray(y)

# %%
# Split the data set in a training set (75%) and a test set (25%)
X_train, X_test, y_train, y_test = train_test_split(
  X,
  y,
  test_size=0.25
)

# %% [markdown]
# ## Building Neural network!

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
def create_model(): 
    model = Sequential([
        Dense(64, activation='relu', input_shape=(4,)),
        Dense(128, activation='relu'),
        Dense(128, activation='relu'),
        Dense(128, activation='relu'),
        Dense(64, activation='relu'),
        Dense(64, activation='relu'),
        Dense(64, activation='relu'),
        Dense(3, activation='softmax')
    ])
    return model

# %%
model = create_model()

# %%
# Compile the model
model.compile(
    optimizer='adam', 
    loss='categorical_crossentropy', 
    metrics=['accuracy']
)

# %%
# Fit the model to the training data
history = model.fit(
    X_train, 
    y_train, 
    epochs=200, 
    validation_split=0.25, 
    batch_size=40, 
    verbose=2
)
# Out:
# Train on 84 samples, validate on 28 samples
# Epoch 1/200
# 84/84 - 2s - loss: 1.1128 - accuracy: 0.3333 - val_loss: 1.1058 - val_accuracy: 0.2500
# Epoch 2/200
# 84/84 - 0s - loss: 1.0607 - accuracy: 0.3333 - val_loss: 1.0590 - val_accuracy: 0.2500
# Epoch 3/200
# 84/84 - 0s - loss: 1.0174 - accuracy: 0.3690 - val_loss: 1.0031 - val_accuracy: 0.3214
# Epoch 4/200
# 84/84 - 0s - loss: 0.9657 - accuracy: 0.3571 - val_loss: 0.9609 - val_accuracy: 0.3214
# Epoch 5/200
# 84/84 - 0s - loss: 0.9201 - accuracy: 0.4643 - val_loss: 0.8559 - val_accuracy: 0.5000
# Epoch 6/200
# 84/84 - 0s - loss: 0.8424 - accuracy: 0.7262 - val_loss: 0.7655 - val_accuracy: 0.7500
# Epoch 7/200
# 84/84 - 0s - loss: 0.7604 - accuracy: 0.6667 - val_loss: 0.6813 - val_accuracy: 0.9643
# Epoch 8/200
# 84/84 - 0s - loss: 0.6549 - accuracy: 0.9048 - val_loss: 0.5648 - val_accuracy: 0.7500
# Epoch 9/200
# 84/84 - 0s - loss: 0.6095 - accuracy: 0.6667 - val_loss: 0.5051 - val_accuracy: 0.7500
# Epoch 10/200
# 84/84 - 0s - loss: 0.5549 - accuracy: 0.6667 - val_loss: 0.4585 - val_accuracy: 0.7500
# Epoch 11/200
# 84/84 - 0s - loss: 0.4795 - accuracy: 0.6667 - val_loss: 0.4454 - val_accuracy: 0.8929
# Epoch 12/200
# 84/84 - 0s - loss: 0.4297 - accuracy: 0.8690 - val_loss: 0.4873 - val_accuracy: 0.6429
# Epoch 13/200
# 84/84 - 0s - loss: 0.4047 - accuracy: 0.8452 - val_loss: 0.3920 - val_accuracy: 0.7857
# Epoch 14/200
# 84/84 - 0s - loss: 0.4001 - accuracy: 0.7143 - val_loss: 0.4502 - val_accuracy: 0.6786
# Epoch 15/200
# 84/84 - 0s - loss: 0.3801 - accuracy: 0.7619 - val_loss: 0.3557 - val_accuracy: 0.9643
# Epoch 16/200
# 84/84 - 0s - loss: 0.3401 - accuracy: 0.8690 - val_loss: 0.3210 - val_accuracy: 0.8214
# Epoch 17/200
# 84/84 - 0s - loss: 0.3238 - accuracy: 0.8929 - val_loss: 0.3981 - val_accuracy: 0.7500
# Epoch 18/200
# 84/84 - 0s - loss: 0.3048 - accuracy: 0.9048 - val_loss: 0.2634 - val_accuracy: 0.8929
# Epoch 19/200
# 84/84 - 0s - loss: 0.2577 - accuracy: 0.9167 - val_loss: 0.2426 - val_accuracy: 0.9643
# Epoch 20/200
# 84/84 - 0s - loss: 0.2128 - accuracy: 0.9881 - val_loss: 0.2108 - val_accuracy: 0.9643
# Epoch 21/200
# 84/84 - 0s - loss: 0.1866 - accuracy: 0.9762 - val_loss: 0.1888 - val_accuracy: 0.9643
# Epoch 22/200
# 84/84 - 0s - loss: 0.1705 - accuracy: 0.9762 - val_loss: 0.2093 - val_accuracy: 0.8929
# Epoch 23/200
# 84/84 - 0s - loss: 0.1632 - accuracy: 0.9524 - val_loss: 0.4320 - val_accuracy: 0.7143
# Epoch 24/200
# 84/84 - 0s - loss: 0.2341 - accuracy: 0.8929 - val_loss: 0.3185 - val_accuracy: 0.8214
# Epoch 25/200
# 84/84 - 0s - loss: 0.2403 - accuracy: 0.8810 - val_loss: 0.4860 - val_accuracy: 0.7500
# Epoch 26/200
# 84/84 - 0s - loss: 0.2982 - accuracy: 0.8571 - val_loss: 0.3789 - val_accuracy: 0.8214
# Epoch 27/200
# 84/84 - 0s - loss: 0.3579 - accuracy: 0.8095 - val_loss: 0.4166 - val_accuracy: 0.7857
# Epoch 28/200
# 84/84 - 0s - loss: 0.8221 - accuracy: 0.7143 - val_loss: 0.1308 - val_accuracy: 0.9643
# Epoch 29/200
# 84/84 - 0s - loss: 0.3634 - accuracy: 0.8452 - val_loss: 0.7408 - val_accuracy: 0.7500
# Epoch 30/200
# 84/84 - 0s - loss: 1.0110 - accuracy: 0.6667 - val_loss: 0.6604 - val_accuracy: 0.7500
# Epoch 31/200
# 84/84 - 0s - loss: 0.8265 - accuracy: 0.6667 - val_loss: 0.4691 - val_accuracy: 0.7500
# Epoch 32/200
# 84/84 - 0s - loss: 0.5397 - accuracy: 0.6667 - val_loss: 0.4311 - val_accuracy: 0.7500
# Epoch 33/200
# 84/84 - 0s - loss: 0.4469 - accuracy: 0.6786 - val_loss: 0.5151 - val_accuracy: 0.5357
# Epoch 34/200
# 84/84 - 0s - loss: 0.4597 - accuracy: 0.6667 - val_loss: 0.5690 - val_accuracy: 0.5357
# Epoch 35/200
# 84/84 - 0s - loss: 0.4756 - accuracy: 0.6667 - val_loss: 0.5527 - val_accuracy: 0.5357
# Epoch 36/200
# 84/84 - 0s - loss: 0.4569 - accuracy: 0.6667 - val_loss: 0.4996 - val_accuracy: 0.5357
# Epoch 37/200
# 84/84 - 0s - loss: 0.4331 - accuracy: 0.6667 - val_loss: 0.4620 - val_accuracy: 0.8929
# Epoch 38/200
# 84/84 - 0s - loss: 0.4157 - accuracy: 0.9167 - val_loss: 0.4145 - val_accuracy: 0.8214
# Epoch 39/200
# 84/84 - 0s - loss: 0.4135 - accuracy: 0.7500 - val_loss: 0.3978 - val_accuracy: 0.7857
# Epoch 40/200
# 84/84 - 0s - loss: 0.4022 - accuracy: 0.6905 - val_loss: 0.3888 - val_accuracy: 0.8214
# Epoch 41/200
# 84/84 - 0s - loss: 0.3834 - accuracy: 0.8214 - val_loss: 0.3962 - val_accuracy: 0.8929
# Epoch 42/200
# 84/84 - 0s - loss: 0.3703 - accuracy: 0.9762 - val_loss: 0.4394 - val_accuracy: 0.8214
# Epoch 43/200
# 84/84 - 0s - loss: 0.3713 - accuracy: 0.8690 - val_loss: 0.4308 - val_accuracy: 0.8214
# Epoch 44/200
# 84/84 - 0s - loss: 0.3513 - accuracy: 0.8929 - val_loss: 0.3631 - val_accuracy: 0.9643
# Epoch 45/200
# 84/84 - 0s - loss: 0.3176 - accuracy: 0.9762 - val_loss: 0.3229 - val_accuracy: 0.8929
# Epoch 46/200
# 84/84 - 0s - loss: 0.2969 - accuracy: 0.9524 - val_loss: 0.2942 - val_accuracy: 0.8929
# Epoch 47/200
# 84/84 - 0s - loss: 0.2692 - accuracy: 0.9643 - val_loss: 0.2908 - val_accuracy: 0.9643
# Epoch 48/200
# 84/84 - 0s - loss: 0.2400 - accuracy: 0.9762 - val_loss: 0.2653 - val_accuracy: 0.9643
# Epoch 49/200
# 84/84 - 0s - loss: 0.2091 - accuracy: 0.9524 - val_loss: 0.2329 - val_accuracy: 0.9643
# Epoch 50/200
# 84/84 - 0s - loss: 0.1847 - accuracy: 0.9524 - val_loss: 0.1820 - val_accuracy: 0.9643
# Epoch 51/200
# 84/84 - 0s - loss: 0.1433 - accuracy: 0.9762 - val_loss: 0.1585 - val_accuracy: 0.9643
# Epoch 52/200
# 84/84 - 0s - loss: 0.1316 - accuracy: 0.9524 - val_loss: 0.1468 - val_accuracy: 0.9643
# Epoch 53/200
# 84/84 - 0s - loss: 0.1120 - accuracy: 0.9405 - val_loss: 0.1243 - val_accuracy: 1.0000
# Epoch 54/200
# 84/84 - 0s - loss: 0.0959 - accuracy: 0.9762 - val_loss: 0.1123 - val_accuracy: 1.0000
# Epoch 55/200
# 84/84 - 0s - loss: 0.0835 - accuracy: 0.9762 - val_loss: 0.1028 - val_accuracy: 1.0000
# Epoch 56/200
# 84/84 - 0s - loss: 0.0766 - accuracy: 0.9643 - val_loss: 0.0950 - val_accuracy: 0.9643
# Epoch 57/200
# 84/84 - 0s - loss: 0.0701 - accuracy: 0.9762 - val_loss: 0.0908 - val_accuracy: 0.9643
# Epoch 58/200
# 84/84 - 0s - loss: 0.0693 - accuracy: 0.9762 - val_loss: 0.1937 - val_accuracy: 0.8929
# Epoch 59/200
# 84/84 - 0s - loss: 0.2687 - accuracy: 0.9167 - val_loss: 0.2118 - val_accuracy: 0.8929
# Epoch 60/200
# 84/84 - 0s - loss: 0.5769 - accuracy: 0.7857 - val_loss: 0.7726 - val_accuracy: 0.7857
# Epoch 61/200
# 84/84 - 0s - loss: 1.0764 - accuracy: 0.6786 - val_loss: 0.6349 - val_accuracy: 0.7857
# Epoch 62/200
# 84/84 - 0s - loss: 0.8043 - accuracy: 0.6786 - val_loss: 0.4312 - val_accuracy: 0.7857
# Epoch 63/200
# 84/84 - 0s - loss: 0.5458 - accuracy: 0.6786 - val_loss: 0.3642 - val_accuracy: 0.7857
# Epoch 64/200
# 84/84 - 0s - loss: 0.4207 - accuracy: 0.7024 - val_loss: 0.3771 - val_accuracy: 0.8214
# Epoch 65/200
# 84/84 - 0s - loss: 0.3835 - accuracy: 0.8452 - val_loss: 0.3822 - val_accuracy: 0.8929
# Epoch 66/200
# 84/84 - 0s - loss: 0.3257 - accuracy: 0.9405 - val_loss: 0.3560 - val_accuracy: 1.0000
# Epoch 67/200
# 84/84 - 0s - loss: 0.2532 - accuracy: 0.9643 - val_loss: 0.3011 - val_accuracy: 0.9286
# Epoch 68/200
# 84/84 - 0s - loss: 0.2288 - accuracy: 0.9286 - val_loss: 0.2517 - val_accuracy: 0.9286
# Epoch 69/200
# 84/84 - 0s - loss: 0.1811 - accuracy: 0.9405 - val_loss: 0.2108 - val_accuracy: 0.9286
# Epoch 70/200
# 84/84 - 0s - loss: 0.1492 - accuracy: 0.9643 - val_loss: 0.2271 - val_accuracy: 0.8929
# Epoch 71/200
# 84/84 - 0s - loss: 0.1549 - accuracy: 0.9524 - val_loss: 0.2092 - val_accuracy: 0.8929
# Epoch 72/200
# 84/84 - 0s - loss: 0.1282 - accuracy: 0.9524 - val_loss: 0.1341 - val_accuracy: 0.9286
# Epoch 73/200
# 84/84 - 0s - loss: 0.0867 - accuracy: 0.9762 - val_loss: 0.0983 - val_accuracy: 0.9643
# Epoch 74/200
# 84/84 - 0s - loss: 0.0766 - accuracy: 0.9762 - val_loss: 0.1166 - val_accuracy: 0.9286
# Epoch 75/200
# 84/84 - 0s - loss: 0.0758 - accuracy: 0.9762 - val_loss: 0.0777 - val_accuracy: 0.9643
# Epoch 76/200
# 84/84 - 0s - loss: 0.0617 - accuracy: 0.9762 - val_loss: 0.0674 - val_accuracy: 1.0000
# Epoch 77/200
# 84/84 - 0s - loss: 0.0543 - accuracy: 0.9762 - val_loss: 0.0727 - val_accuracy: 0.9643
# Epoch 78/200
# 84/84 - 0s - loss: 0.0580 - accuracy: 0.9762 - val_loss: 0.0626 - val_accuracy: 0.9643
# Epoch 79/200
# 84/84 - 0s - loss: 0.0548 - accuracy: 0.9762 - val_loss: 0.0604 - val_accuracy: 0.9643
# Epoch 80/200
# 84/84 - 0s - loss: 0.0575 - accuracy: 0.9762 - val_loss: 0.0762 - val_accuracy: 0.9643
# Epoch 81/200
# 84/84 - 0s - loss: 0.0595 - accuracy: 0.9762 - val_loss: 0.0520 - val_accuracy: 1.0000
# Epoch 82/200
# 84/84 - 0s - loss: 0.0554 - accuracy: 0.9762 - val_loss: 0.0605 - val_accuracy: 0.9643
# Epoch 83/200
# 84/84 - 0s - loss: 0.0514 - accuracy: 0.9762 - val_loss: 0.0517 - val_accuracy: 1.0000
# Epoch 84/200
# 84/84 - 0s - loss: 0.0497 - accuracy: 0.9762 - val_loss: 0.0513 - val_accuracy: 1.0000
# Epoch 85/200
# 84/84 - 0s - loss: 0.0494 - accuracy: 0.9762 - val_loss: 0.0487 - val_accuracy: 1.0000
# Epoch 86/200
# 84/84 - 0s - loss: 0.0522 - accuracy: 0.9643 - val_loss: 0.0714 - val_accuracy: 0.9643
# Epoch 87/200
# 84/84 - 0s - loss: 0.0756 - accuracy: 0.9762 - val_loss: 0.3010 - val_accuracy: 0.8929
# Epoch 88/200
# 84/84 - 0s - loss: 0.1537 - accuracy: 0.9524 - val_loss: 0.1214 - val_accuracy: 0.9286
# Epoch 89/200
# 84/84 - 0s - loss: 0.0618 - accuracy: 0.9762 - val_loss: 0.0452 - val_accuracy: 1.0000
# Epoch 90/200
# 84/84 - 0s - loss: 0.0609 - accuracy: 0.9762 - val_loss: 0.1029 - val_accuracy: 0.9286
# Epoch 91/200
# 84/84 - 0s - loss: 0.0770 - accuracy: 0.9762 - val_loss: 0.0457 - val_accuracy: 1.0000
# Epoch 92/200
# 84/84 - 0s - loss: 0.0633 - accuracy: 0.9643 - val_loss: 0.4124 - val_accuracy: 0.8929
# Epoch 93/200
# 84/84 - 0s - loss: 0.3152 - accuracy: 0.9048 - val_loss: 0.0669 - val_accuracy: 0.9643
# Epoch 94/200
# 84/84 - 0s - loss: 0.0721 - accuracy: 0.9762 - val_loss: 0.3892 - val_accuracy: 0.8929
# Epoch 95/200
# 84/84 - 0s - loss: 0.2417 - accuracy: 0.8929 - val_loss: 0.1695 - val_accuracy: 0.8929
# Epoch 96/200
# 84/84 - 0s - loss: 0.0549 - accuracy: 0.9881 - val_loss: 0.4945 - val_accuracy: 0.8571
# Epoch 97/200
# 84/84 - 0s - loss: 0.3764 - accuracy: 0.9048 - val_loss: 0.0602 - val_accuracy: 1.0000
# Epoch 98/200
# 84/84 - 0s - loss: 0.1016 - accuracy: 0.9762 - val_loss: 0.5706 - val_accuracy: 0.8214
# Epoch 99/200
# 84/84 - 0s - loss: 0.5320 - accuracy: 0.8095 - val_loss: 0.5540 - val_accuracy: 0.8214
# Epoch 100/200
# 84/84 - 0s - loss: 0.4860 - accuracy: 0.8214 - val_loss: 0.2719 - val_accuracy: 0.8929
# Epoch 101/200
# 84/84 - 0s - loss: 0.1244 - accuracy: 0.9524 - val_loss: 0.0950 - val_accuracy: 0.9643
# Epoch 102/200
# 84/84 - 0s - loss: 0.0880 - accuracy: 0.9762 - val_loss: 0.2383 - val_accuracy: 0.8929
# Epoch 103/200
# 84/84 - 0s - loss: 0.1710 - accuracy: 0.9286 - val_loss: 0.1087 - val_accuracy: 0.9643
# Epoch 104/200
# 84/84 - 0s - loss: 0.0786 - accuracy: 0.9762 - val_loss: 0.1128 - val_accuracy: 0.9643
# Epoch 105/200
# 84/84 - 0s - loss: 0.0779 - accuracy: 0.9762 - val_loss: 0.1207 - val_accuracy: 0.9286
# Epoch 106/200
# 84/84 - 0s - loss: 0.0781 - accuracy: 0.9762 - val_loss: 0.1114 - val_accuracy: 0.9286
# Epoch 107/200
# 84/84 - 0s - loss: 0.0719 - accuracy: 0.9762 - val_loss: 0.0888 - val_accuracy: 1.0000
# Epoch 108/200
# 84/84 - 0s - loss: 0.0651 - accuracy: 0.9762 - val_loss: 0.0858 - val_accuracy: 1.0000
# Epoch 109/200
# 84/84 - 0s - loss: 0.0675 - accuracy: 0.9881 - val_loss: 0.0806 - val_accuracy: 1.0000
# Epoch 110/200
# 84/84 - 0s - loss: 0.0632 - accuracy: 0.9881 - val_loss: 0.0712 - val_accuracy: 1.0000
# Epoch 111/200
# 84/84 - 0s - loss: 0.0557 - accuracy: 0.9762 - val_loss: 0.0752 - val_accuracy: 0.9643
# Epoch 112/200
# 84/84 - 0s - loss: 0.0583 - accuracy: 0.9762 - val_loss: 0.0773 - val_accuracy: 0.9643
# Epoch 113/200
# 84/84 - 0s - loss: 0.0614 - accuracy: 0.9762 - val_loss: 0.0838 - val_accuracy: 0.9643
# Epoch 114/200
# 84/84 - 0s - loss: 0.0609 - accuracy: 0.9762 - val_loss: 0.0621 - val_accuracy: 1.0000
# Epoch 115/200
# 84/84 - 0s - loss: 0.0524 - accuracy: 0.9762 - val_loss: 0.0570 - val_accuracy: 1.0000
# Epoch 116/200
# 84/84 - 0s - loss: 0.0500 - accuracy: 0.9762 - val_loss: 0.0577 - val_accuracy: 1.0000
# Epoch 117/200
# 84/84 - 0s - loss: 0.0623 - accuracy: 0.9762 - val_loss: 0.1115 - val_accuracy: 0.9286
# Epoch 118/200
# 84/84 - 0s - loss: 0.0748 - accuracy: 0.9762 - val_loss: 0.0516 - val_accuracy: 1.0000
# Epoch 119/200
# 84/84 - 0s - loss: 0.0756 - accuracy: 0.9643 - val_loss: 0.0738 - val_accuracy: 0.9643
# Epoch 120/200
# 84/84 - 0s - loss: 0.0768 - accuracy: 0.9643 - val_loss: 0.1395 - val_accuracy: 0.9286
# Epoch 121/200
# 84/84 - 0s - loss: 0.0808 - accuracy: 0.9762 - val_loss: 0.0811 - val_accuracy: 0.9643
# Epoch 122/200
# 84/84 - 0s - loss: 0.0564 - accuracy: 0.9762 - val_loss: 0.0645 - val_accuracy: 1.0000
# Epoch 123/200
# 84/84 - 0s - loss: 0.0541 - accuracy: 0.9881 - val_loss: 0.0783 - val_accuracy: 0.9643
# Epoch 124/200
# 84/84 - 0s - loss: 0.0606 - accuracy: 0.9881 - val_loss: 0.0642 - val_accuracy: 1.0000
# Epoch 125/200
# 84/84 - 0s - loss: 0.0508 - accuracy: 0.9762 - val_loss: 0.1090 - val_accuracy: 0.9286
# Epoch 126/200
# 84/84 - 0s - loss: 0.0769 - accuracy: 0.9643 - val_loss: 0.0961 - val_accuracy: 0.9286
# Epoch 127/200
# 84/84 - 0s - loss: 0.0493 - accuracy: 0.9762 - val_loss: 0.1044 - val_accuracy: 0.9286
# Epoch 128/200
# 84/84 - 0s - loss: 0.0834 - accuracy: 0.9524 - val_loss: 0.1204 - val_accuracy: 0.9286
# Epoch 129/200
# 84/84 - 0s - loss: 0.0795 - accuracy: 0.9524 - val_loss: 0.0667 - val_accuracy: 1.0000
# Epoch 130/200
# 84/84 - 0s - loss: 0.0482 - accuracy: 0.9762 - val_loss: 0.1073 - val_accuracy: 0.9286
# Epoch 131/200
# 84/84 - 0s - loss: 0.0741 - accuracy: 0.9643 - val_loss: 0.1413 - val_accuracy: 0.8929
# Epoch 132/200
# 84/84 - 0s - loss: 0.0814 - accuracy: 0.9643 - val_loss: 0.1044 - val_accuracy: 0.9286
# Epoch 133/200
# 84/84 - 0s - loss: 0.0593 - accuracy: 0.9762 - val_loss: 0.0637 - val_accuracy: 1.0000
# Epoch 134/200
# 84/84 - 0s - loss: 0.0678 - accuracy: 0.9643 - val_loss: 0.0865 - val_accuracy: 0.9643
# Epoch 135/200
# 84/84 - 0s - loss: 0.0615 - accuracy: 0.9881 - val_loss: 0.0649 - val_accuracy: 1.0000
# Epoch 136/200
# 84/84 - 0s - loss: 0.0591 - accuracy: 0.9762 - val_loss: 0.1818 - val_accuracy: 0.8929
# Epoch 137/200
# 84/84 - 0s - loss: 0.1039 - accuracy: 0.9643 - val_loss: 0.1930 - val_accuracy: 0.8929
# Epoch 138/200
# 84/84 - 0s - loss: 0.0997 - accuracy: 0.9643 - val_loss: 0.0987 - val_accuracy: 0.9286
# Epoch 139/200
# 84/84 - 0s - loss: 0.0584 - accuracy: 0.9762 - val_loss: 0.0569 - val_accuracy: 1.0000
# Epoch 140/200
# 84/84 - 0s - loss: 0.0481 - accuracy: 0.9762 - val_loss: 0.0553 - val_accuracy: 1.0000
# Epoch 141/200
# 84/84 - 0s - loss: 0.0475 - accuracy: 0.9762 - val_loss: 0.0559 - val_accuracy: 1.0000
# Epoch 142/200
# 84/84 - 0s - loss: 0.0480 - accuracy: 0.9762 - val_loss: 0.0519 - val_accuracy: 1.0000
# Epoch 143/200
# 84/84 - 0s - loss: 0.0462 - accuracy: 0.9762 - val_loss: 0.0592 - val_accuracy: 1.0000
# Epoch 144/200
# 84/84 - 0s - loss: 0.0505 - accuracy: 0.9762 - val_loss: 0.0563 - val_accuracy: 1.0000
# Epoch 145/200
# 84/84 - 0s - loss: 0.0508 - accuracy: 0.9762 - val_loss: 0.0456 - val_accuracy: 1.0000
# Epoch 146/200
# 84/84 - 0s - loss: 0.0456 - accuracy: 0.9762 - val_loss: 0.0479 - val_accuracy: 1.0000
# Epoch 147/200
# 84/84 - 0s - loss: 0.0459 - accuracy: 0.9881 - val_loss: 0.0515 - val_accuracy: 1.0000
# Epoch 148/200
# 84/84 - 0s - loss: 0.0445 - accuracy: 0.9762 - val_loss: 0.1853 - val_accuracy: 0.8929
# Epoch 149/200
# 84/84 - 0s - loss: 0.1032 - accuracy: 0.9643 - val_loss: 0.1993 - val_accuracy: 0.8929
# Epoch 150/200
# 84/84 - 0s - loss: 0.0978 - accuracy: 0.9643 - val_loss: 0.0893 - val_accuracy: 0.9286
# Epoch 151/200
# 84/84 - 0s - loss: 0.0596 - accuracy: 0.9762 - val_loss: 0.0647 - val_accuracy: 0.9643
# Epoch 152/200
# 84/84 - 0s - loss: 0.0697 - accuracy: 0.9762 - val_loss: 0.0721 - val_accuracy: 0.9643
# Epoch 153/200
# 84/84 - 0s - loss: 0.0485 - accuracy: 0.9881 - val_loss: 0.0469 - val_accuracy: 1.0000
# Epoch 154/200
# 84/84 - 0s - loss: 0.0474 - accuracy: 0.9762 - val_loss: 0.0710 - val_accuracy: 0.9643
# Epoch 155/200
# 84/84 - 0s - loss: 0.0541 - accuracy: 0.9762 - val_loss: 0.0499 - val_accuracy: 1.0000
# Epoch 156/200
# 84/84 - 0s - loss: 0.0952 - accuracy: 0.9405 - val_loss: 0.2469 - val_accuracy: 0.8929
# Epoch 157/200
# 84/84 - 0s - loss: 0.1322 - accuracy: 0.9405 - val_loss: 0.0514 - val_accuracy: 1.0000
# Epoch 158/200
# 84/84 - 0s - loss: 0.0583 - accuracy: 0.9762 - val_loss: 0.0790 - val_accuracy: 0.9286
# Epoch 159/200
# 84/84 - 0s - loss: 0.0481 - accuracy: 0.9762 - val_loss: 0.0890 - val_accuracy: 0.9286
# Epoch 160/200
# 84/84 - 0s - loss: 0.0715 - accuracy: 0.9643 - val_loss: 0.0588 - val_accuracy: 1.0000
# Epoch 161/200
# 84/84 - 0s - loss: 0.0560 - accuracy: 0.9762 - val_loss: 0.2659 - val_accuracy: 0.8929
# Epoch 162/200
# 84/84 - 0s - loss: 0.1556 - accuracy: 0.9405 - val_loss: 0.2839 - val_accuracy: 0.8929
# Epoch 163/200
# 84/84 - 0s - loss: 0.1497 - accuracy: 0.9405 - val_loss: 0.1177 - val_accuracy: 0.9286
# Epoch 164/200
# 84/84 - 0s - loss: 0.0478 - accuracy: 0.9762 - val_loss: 0.1219 - val_accuracy: 0.9286
# Epoch 165/200
# 84/84 - 0s - loss: 0.1287 - accuracy: 0.9405 - val_loss: 0.1220 - val_accuracy: 0.9286
# Epoch 166/200
# 84/84 - 0s - loss: 0.0695 - accuracy: 0.9762 - val_loss: 0.0817 - val_accuracy: 0.9286
# Epoch 167/200
# 84/84 - 0s - loss: 0.0551 - accuracy: 0.9762 - val_loss: 0.2169 - val_accuracy: 0.8929
# Epoch 168/200
# 84/84 - 0s - loss: 0.1235 - accuracy: 0.9524 - val_loss: 0.2116 - val_accuracy: 0.8929
# Epoch 169/200
# 84/84 - 0s - loss: 0.1065 - accuracy: 0.9524 - val_loss: 0.1057 - val_accuracy: 0.9286
# Epoch 170/200
# 84/84 - 0s - loss: 0.0532 - accuracy: 0.9762 - val_loss: 0.0663 - val_accuracy: 1.0000
# Epoch 171/200
# 84/84 - 0s - loss: 0.0538 - accuracy: 1.0000 - val_loss: 0.0976 - val_accuracy: 0.9286
# Epoch 172/200
# 84/84 - 0s - loss: 0.0690 - accuracy: 0.9643 - val_loss: 0.0560 - val_accuracy: 1.0000
# Epoch 173/200
# 84/84 - 0s - loss: 0.0556 - accuracy: 0.9762 - val_loss: 0.0891 - val_accuracy: 0.9286
# Epoch 174/200
# 84/84 - 0s - loss: 0.0577 - accuracy: 0.9762 - val_loss: 0.1156 - val_accuracy: 0.9286
# Epoch 175/200
# 84/84 - 0s - loss: 0.0660 - accuracy: 0.9762 - val_loss: 0.0965 - val_accuracy: 0.9286
# Epoch 176/200
# 84/84 - 0s - loss: 0.0605 - accuracy: 0.9762 - val_loss: 0.0752 - val_accuracy: 0.9286
# Epoch 177/200
# 84/84 - 0s - loss: 0.0536 - accuracy: 0.9762 - val_loss: 0.0708 - val_accuracy: 0.9286
# Epoch 178/200
# 84/84 - 0s - loss: 0.0524 - accuracy: 0.9762 - val_loss: 0.0452 - val_accuracy: 1.0000
# Epoch 179/200
# 84/84 - 0s - loss: 0.0440 - accuracy: 0.9762 - val_loss: 0.0441 - val_accuracy: 1.0000
# Epoch 180/200
# 84/84 - 0s - loss: 0.0427 - accuracy: 0.9881 - val_loss: 0.0474 - val_accuracy: 1.0000
# Epoch 181/200
# 84/84 - 0s - loss: 0.0443 - accuracy: 0.9881 - val_loss: 0.0430 - val_accuracy: 1.0000
# Epoch 182/200
# 84/84 - 0s - loss: 0.0413 - accuracy: 0.9881 - val_loss: 0.0378 - val_accuracy: 1.0000
# Epoch 183/200
# 84/84 - 0s - loss: 0.0425 - accuracy: 0.9762 - val_loss: 0.0370 - val_accuracy: 1.0000
# Epoch 184/200
# 84/84 - 0s - loss: 0.0423 - accuracy: 0.9762 - val_loss: 0.0353 - val_accuracy: 1.0000
# Epoch 185/200
# 84/84 - 0s - loss: 0.0414 - accuracy: 0.9762 - val_loss: 0.0340 - val_accuracy: 1.0000
# Epoch 186/200
# 84/84 - 0s - loss: 0.0425 - accuracy: 0.9762 - val_loss: 0.1385 - val_accuracy: 0.9286
# Epoch 187/200
# 84/84 - 0s - loss: 0.1972 - accuracy: 0.9286 - val_loss: 0.0903 - val_accuracy: 0.9286
# Epoch 188/200
# 84/84 - 0s - loss: 0.0386 - accuracy: 1.0000 - val_loss: 0.0877 - val_accuracy: 0.9286
# Epoch 189/200
# 84/84 - 0s - loss: 0.0753 - accuracy: 0.9762 - val_loss: 0.2201 - val_accuracy: 0.8929
# Epoch 190/200
# 84/84 - 0s - loss: 0.1073 - accuracy: 0.9643 - val_loss: 0.1444 - val_accuracy: 0.9286
# Epoch 191/200
# 84/84 - 0s - loss: 0.0738 - accuracy: 0.9762 - val_loss: 0.0387 - val_accuracy: 1.0000
# Epoch 192/200
# 84/84 - 0s - loss: 0.0369 - accuracy: 0.9881 - val_loss: 0.0860 - val_accuracy: 0.9286
# Epoch 193/200
# 84/84 - 0s - loss: 0.0648 - accuracy: 0.9643 - val_loss: 0.0401 - val_accuracy: 1.0000
# Epoch 194/200
# 84/84 - 0s - loss: 0.0404 - accuracy: 0.9881 - val_loss: 0.0550 - val_accuracy: 1.0000
# Epoch 195/200
# 84/84 - 0s - loss: 0.0522 - accuracy: 0.9762 - val_loss: 0.0421 - val_accuracy: 1.0000
# Epoch 196/200
# 84/84 - 0s - loss: 0.0867 - accuracy: 0.9524 - val_loss: 0.0454 - val_accuracy: 1.0000
# Epoch 197/200
# 84/84 - 0s - loss: 0.0746 - accuracy: 0.9643 - val_loss: 0.4960 - val_accuracy: 0.8214
# Epoch 198/200
# 84/84 - 0s - loss: 0.3546 - accuracy: 0.8571 - val_loss: 0.3908 - val_accuracy: 0.8929
# Epoch 199/200
# 84/84 - 0s - loss: 0.1836 - accuracy: 0.9167 - val_loss: 0.0633 - val_accuracy: 1.0000
# Epoch 200/200
# 84/84 - 0s - loss: 0.0599 - accuracy: 0.9643 - val_loss: 0.3740 - val_accuracy: 0.8929

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'

def plot_metric(history, metric):
    train_metrics = history.history[metric]
    val_metrics = history.history['val_'+metric]
    epochs = range(1, len(train_metrics) + 1)
    plt.plot(epochs, train_metrics)
    plt.plot(epochs, val_metrics)
    plt.title('Training and validation '+ metric)
    plt.xlabel("Epochs")
    plt.ylabel(metric)
    plt.legend(["train_"+metric, 'val_'+metric])
    plt.show()

# %%
plot_metric(history, 'accuracy')

# %%
plot_metric(history, 'loss')

# %% [markdown]
# From the above graph, we can see that the model has overfitted the training data, so it outperforms the validation set.

# %% [markdown]
# ### Early Stopping with default settings

# %%
from tensorflow.keras.callbacks import EarlyStopping

early_stopping = EarlyStopping() # by default, monitor='val_loss' and patience=1

# %% [markdown]
# - monitor='val_loss': to use validation loss as performance measure to terminate the training.
# - patience=0: is the number of epochs with no improvement. The value 0 means the training is terminated as soon as the performance measure gets worse from one epoch to the next.

# %%
#pass the callback object to model.fit() method.
history = model.fit(
    X_train, 
    y_train, 
    epochs=200, 
    validation_split=0.25, 
    batch_size=40, 
    verbose=2,
    callbacks=[early_stopping]
)
# Out:
# Train on 84 samples, validate on 28 samples
# Epoch 1/200
# 84/84 - 0s - loss: 0.1046 - accuracy: 0.9643 - val_loss: 0.0868 - val_accuracy: 0.9286
# Epoch 2/200
# 84/84 - 0s - loss: 0.0577 - accuracy: 0.9762 - val_loss: 0.0468 - val_accuracy: 1.0000
# Epoch 3/200
# 84/84 - 0s - loss: 0.0391 - accuracy: 1.0000 - val_loss: 0.0558 - val_accuracy: 1.0000

# %% [markdown]
# The training gets terminated at Epoch 2or3 due to the increase of val_loss value and that is exactly the conditions monitor='val_loss' and patience=0

# %%
plot_metric(history, 'loss')

# %% [markdown]
# plot shows that validation loss increases after epoch 2

# %% [markdown]
# ### Few more features in Early Stopping
# - **min_delta**: Minimum change in the monitored quantity to qualify as an improvement, i.e. an absolute change of less than min_delta, will count as no improvement.
# - **mode='auto'**: Should be one of auto, min or max. In 'min' mode, training will stop when the quantity monitored has stopped decreasing; in 'max' mode it will stop when the quantity monitored has stopped increasing; in 'auto' mode, the direction is automatically inferred from the name of the monitored quantity.

# %%
custom_early_stopping = EarlyStopping(
    monitor='val_accuracy', 
    patience=8, 
    min_delta=0.001, 
    mode='max'
)

# %%
history = model.fit(
    X_train, 
    y_train, 
    epochs=200, 
    validation_split=0.25, 
    batch_size=40, 
    verbose=2,
    callbacks=[custom_early_stopping]
)
# Out:
# Train on 84 samples, validate on 28 samples
# Epoch 1/200
# 84/84 - 0s - loss: 0.0422 - accuracy: 0.9762 - val_loss: 0.0474 - val_accuracy: 1.0000
# Epoch 2/200
# 84/84 - 0s - loss: 0.0421 - accuracy: 0.9762 - val_loss: 0.0363 - val_accuracy: 1.0000
# Epoch 3/200
# 84/84 - 0s - loss: 0.0372 - accuracy: 0.9762 - val_loss: 0.0409 - val_accuracy: 1.0000
# Epoch 4/200
# 84/84 - 0s - loss: 0.0384 - accuracy: 0.9881 - val_loss: 0.0460 - val_accuracy: 1.0000
# Epoch 5/200
# 84/84 - 0s - loss: 0.0389 - accuracy: 0.9881 - val_loss: 0.0361 - val_accuracy: 1.0000
# Epoch 6/200
# 84/84 - 0s - loss: 0.0368 - accuracy: 0.9762 - val_loss: 0.0315 - val_accuracy: 1.0000
# Epoch 7/200
# 84/84 - 0s - loss: 0.0373 - accuracy: 0.9762 - val_loss: 0.0304 - val_accuracy: 1.0000
# Epoch 8/200
# 84/84 - 0s - loss: 0.0376 - accuracy: 0.9762 - val_loss: 0.0305 - val_accuracy: 1.0000
# Epoch 9/200
# 84/84 - 0s - loss: 0.0388 - accuracy: 0.9762 - val_loss: 0.0692 - val_accuracy: 0.9643

# %% [markdown]
# monitor='val_accuracy' to use validation accuracy as performance measure to terminate the training. patience=8 means the training is terminated as soon as 8 epochs with no improvement. min_delta=0.001 means the validation accuracy has to improve by at least 0.001 for it to count as an improvement. mode='max' means it will stop when the quantity monitored has stopped increasing.

# %%
plot_metric(history, 'accuracy')

# %% [markdown]
# This time, the training gets terminated at Epoch 9 as there are 8 epochs with no improvement on validation accuracy (It has to be ≥ 0.001 to count as an improvement). For a clear picture, let’s look at a plot representation of accuracy by running plot_metric(history, 'accuracy'). In the below graph, validation accuracy is shown in orange and it’s clear that validation accuracy hasn’t got any improvement.
